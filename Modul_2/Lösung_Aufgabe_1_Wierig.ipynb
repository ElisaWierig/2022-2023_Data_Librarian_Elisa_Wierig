# %%
import json

# %%
url = "https://www.bibsonomy.org/json/search/archiv?items=1000duplicates=merged"

# %%
import pandas as pd

# %%
import requests
url = "https://www.bibsonomy.org/json/search/archiv?items=1000duplicates=merged"
result = requests.get(url)
data = result.json()

# %%
data.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
type(data["items"])
# Out:
# list

# %%
df_bibsonomy = pd.DataFrame(data["items"])

# %%
df_bibsonomy
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/af415eb8c9d33dea...
# 1        Bookmark  https://www.bibsonomy.org/url/af415eb8c9d33dea...
# 2        Bookmark  https://www.bibsonomy.org/url/9cdd5a773d295135...
# 3        Bookmark  https://www.bibsonomy.org/url/3fb93a670418e1e0...
# 4        Bookmark  https://www.bibsonomy.org/url/0b91790b2a66e688...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/2c2163e8a6447...
# 1996  Publication  https://www.bibsonomy.org/bibtex/2afb16ce95869...
# 1997  Publication  https://www.bibsonomy.org/bibtex/2c03c4cc8b62c...
# 1998  Publication  https://www.bibsonomy.org/bibtex/270dd94f90714...
# 1999  Publication  https://www.bibsonomy.org/bibtex/2f56cfb4368da...
#
#                                               tags  \
# 0              [Archiv, Text, Sammlung, Blindtext]
# ...

# %%
data1 = json.load(open("archiv.json"))
data2 = json.load(open("museum.json"))

# %%
data1.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
df_search1 = pd.DataFrame(data1["items"])
df_search2 = pd.DataFrame(data2["items"])

# %%
df_search1
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/af415eb8c9d33dea...
# 1        Bookmark  https://www.bibsonomy.org/url/af415eb8c9d33dea...
# 2        Bookmark  https://www.bibsonomy.org/url/9cdd5a773d295135...
# 3        Bookmark  https://www.bibsonomy.org/url/3fb93a670418e1e0...
# 4        Bookmark  https://www.bibsonomy.org/url/0b91790b2a66e688...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/2c2163e8a6447...
# 1996  Publication  https://www.bibsonomy.org/bibtex/2afb16ce95869...
# 1997  Publication  https://www.bibsonomy.org/bibtex/2c03c4cc8b62c...
# 1998  Publication  https://www.bibsonomy.org/bibtex/270dd94f90714...
# 1999  Publication  https://www.bibsonomy.org/bibtex/2f56cfb4368da...
#
#                                               tags  \
# 0              [Archiv, Text, Sammlung, Blindtext]
# ...

# %%
df_search2
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/86437676dd8cf3fb...
# 1        Bookmark  https://www.bibsonomy.org/url/faebc9ea51983985...
# 2        Bookmark  https://www.bibsonomy.org/url/b2172a37a0eda9fb...
# 3        Bookmark  https://www.bibsonomy.org/url/ad9e51aa2db4d3ed...
# 4        Bookmark  https://www.bibsonomy.org/url/c56ade403b273284...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/2f7cf5bdb2a6e...
# 1996  Publication  https://www.bibsonomy.org/bibtex/292a012df57c5...
# 1997  Publication  https://www.bibsonomy.org/bibtex/221c15eea2b55...
# 1998  Publication  https://www.bibsonomy.org/bibtex/219bb24d3055b...
# 1999  Publication  https://www.bibsonomy.org/bibtex/2c571235a3931...
#
#                                                    tags  \
# 0     [anthropology, NC, wfu, places, museum, winsto...
# ...

# %%
df_both = pd.concat([df_search1, df_search2])

# %%
df_both
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/af415eb8c9d33dea...
# 1        Bookmark  https://www.bibsonomy.org/url/af415eb8c9d33dea...
# 2        Bookmark  https://www.bibsonomy.org/url/9cdd5a773d295135...
# 3        Bookmark  https://www.bibsonomy.org/url/3fb93a670418e1e0...
# 4        Bookmark  https://www.bibsonomy.org/url/0b91790b2a66e688...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/2f7cf5bdb2a6e...
# 1996  Publication  https://www.bibsonomy.org/bibtex/292a012df57c5...
# 1997  Publication  https://www.bibsonomy.org/bibtex/221c15eea2b55...
# 1998  Publication  https://www.bibsonomy.org/bibtex/219bb24d3055b...
# 1999  Publication  https://www.bibsonomy.org/bibtex/2c571235a3931...
#
#                                               tags  \
# 0              [Archiv, Text, Sammlung, Blindtext]
# ...
